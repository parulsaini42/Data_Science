# %% [markdown]
# ### Mathematical computing in python
#
# **import statistics**
#
# It is suitable for basic statistical calculations in Python scripts or applications where performance is not a critical concern.
#
# **import numpy**
#
# It is commonly used for scientific computing, data analysis, machine learning, and other numerical computing tasks where performance and efficiency are critical.

# %%
import numpy as np

a = list(range(0,20))
a.append(2)

#mean is average of the values
np.mean(a)
# Out:
# 9.142857142857142

# %%
np.median(a)
# Out:
# 9.0

# %%
import statistics
# list is not sorted before calculating median, its simply the middle value.
statistics.median(a)
# Out:
# 9

# %%
statistics.mean(a)
# Out:
# 9.142857142857142

# %%
#frequently occuring values
statistics.mode(a)
# Out:
# 2

# %% [markdown]
# #### standard deviation
#
# Standard deviation is a number that describes how spread out the values are.
#
# A low standard deviation means that most of the numbers are close to the mean (average) value.
#
# A high standard deviation means that the values are spread out over a wider range.
#
# $$
# \sigma = \sqrt{\frac{\sum_{i=1}^{n} (x_i - \mu)^2}{n}}
# $$
#
# Calculate the average of the squared differences between each observation and the mean and then take a squareroot of that

# %%
np.std(a)
# Out:
# 5.849588624410261

# %% [markdown]
# ### variance
#
# Square root of variance is the standard deviation. Therefore, variance aloso talks about the spread of the data. if you multiply the standard deviation by itself, you get the variance!
#
# $$
# \sigma^2 = \frac{\sum_{i=1}^{n} (x_i - \mu)^2}{n}
# $$

# %%
np.var(a)
# Out:
# 34.217687074829925

# %%
pow(np.std(a),2)
# Out:
# 34.21768707482993

# %% [markdown]
# ### percentiles
#
# Gives you a number that describes the value that a given percent of the values are lower than.
#
# eg. 75 percentile means 75% are lower than that  43 years of age

# %%
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]
ages.sort()
ages
# Out:
# [2, 5, 6, 7, 8, 11, 15, 25, 27, 31, 31, 32, 36, 39, 41, 43, 48, 50, 61, 80, 82]

# %%
np.percentile(ages,75)
# Out:
# 43.0

# %% [markdown]
# ### Quartile

# %% [markdown]
# ### Data Distributions
#
# Data distribution can be characterized by several statistical measures, including mean, median, mode, standard deviation, and variance.These measures help to describe the central tendency, spread, and shape of the data.

# %%
##Create and visualize data
import matplotlib.pyplot as plt

x = np.random.uniform(0.0,5.0,250)
plt.hist(x,5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Normal Distribution
#
# 1. Normal distribution, also known as Gaussian distribution, is a continuous probability distribution
#
# 2. It is a bell-shaped curve (PDF) that describes the probability distribution of a random variable that is **symmetric around the mean.**
#
# 3. The normal distribution has two parameters, the mean (μ) and the standard deviation (σ).
#     normal distribution is often used to model the distribution of error terms in linear regression and other statistical models.
#
#     scipy.stats (scientific coputing library), provides functions for calculating the probability density function (PDF), cumulative distribution function (CDF) etc to work with normal distributions.
#
#
# 4. normal distribution is the empirical rule, also known as the 68-95-99.7 rule. i.e %age of values that fall in 1,2 and 3 standard deviations of the mean.
#
# 5. The skewness for a normal distribution is 0.
#
#
# #### PDF
#
#
# A Probability Density Function (PDF) is a mathematical function that describes the likelihood of a continuous random variable taking on a specific value or falling within a particular range of values.
#
# $$
# f(x|\mu, \sigma) = \frac{1}{\sqrt{2\pi\sigma^2}} \exp\left(-\frac{(x - \mu)^2}{2\sigma^2}\right)
# $$
#
# where $x$ is the variable, $\mu$ is the mean, and $\sigma$ is the standard deviation.
#
#
# - Probability density functions are used to describe the probability distribution of continuous random variables. These are variables that can take on any value within a certain range (e.g., height, weight, time).
#
# - Unlike probability mass functions (PMFs) used for discrete random variables, where the probability of each specific value is directly given, a PDF gives the density of probability rather than the probability itself. This means that the area under the curve of a PDF within a certain interval represents the probability of the random variable falling within that interval.
#
# - To find the probability of a continuous random variable falling within a specific range, you need to integrate the PDF over that range. The integral gives the total probability of the variable falling within the specified interval.
#
# - PDFs are typically normalized such that the total area under the curve equals 1. Normalization parameter is as follows:
#
# $$
# \frac{1}{\sqrt{2\pi\sigma^2}}
# $$
#
# - Common probability density functions include the normal distribution, uniform distribution, exponential distribution, and many others.
#
# - Compute the PDF of the normal distribution using the scipy.stats.norm.pdf()

# %%
# This visualization allows you to compare the distribution 
# of the random sample to the theoretical normal distribution.

import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

mu = 0 
sigma = 1

#sample size 1000
sample = np.random.normal(mu, sigma, 1000)

#calculate the PDF for normal distribution 

# np.linspace(start, stop, num) ; get a range of values over x to capture bell shaped PDF
x = np.linspace(mu - 3*sigma, mu+ 3*sigma, 100)
pdf = norm.pdf(x, mu, sigma)

# Plot the histogram of the random sample and the PDF of the normal

plt.hist(sample, bins=30)
plt.show()

# %%
plt.plot(x,pdf)
plt.show()

# %% [markdown]
# ### Skewed Distribution
#
# - A skewed distribution in machine learning refers to a dataset that is not evenly distributed around its mean, or average value.
#
# - In a skewed distribution, the majority of the data points tend to cluster towards one end of the distribution
#
#
# - A skewed data set, typical values fall between the first quartile (Q1) and the third quartile (Q3).
#
#
# - While skewness characterizes the asymmetry of a data distribution ; kurtosis determines the heaviness of the distribution tails.
#
# There are two types of skewed distributions:
#
# 1. Left-skewed (negative-skewed distribution)
#
#
# A left-skewed distribution, has a long tail towards the left side of the distribution, with the **majority of data points towards the right side.**
#
# 2. Right-skewed (positive-skewed distribution)
#
# In contrast, a right-skewed distribution, also known as a , has a long tail towards the right side of the distribution, with the **majority of data points towards the left side.**
#
# #### Skewed Distributions  examples:
# #### Gamma Distribution
#
# The gamma distribution is a continuous probability distribution that is often used to model the time until an event occurs. It's particularly useful for modeling waiting times or durations. The distribution is defined by two parameters: shape (k) and scale (θ). Both values should be greater than 0.
#
# The gamma distribution with a shape parameter greater than 1 shows positive skeweness, whereas less than 1 negative skewed.
#
# #### Beta distribution
#
# Beta distribution with parameters α>β is positive skewed else its negative.
#
# The Beta distribution can be used to analyze probabilistic experiments that have only two possible outcomes:
#
# success, with probability X;
#
# failure, with probability $1-X$.
#
# These experiments are called Bernoulli experiments.
#
# #### Why handling skewed data
# - Skewed distributions can occur in many different types of datasets, such as financial data, social media metrics, or healthcare records.
#
# - Skewed data must be handled as it can lead to biased predictions and inaccurate results in some cases and may require preprocessing techniques such as normalization or data transformation to improve the performance of the model. Degrades the model’s ability (especially regression based models) to describe typical cases as it has to deal with rare cases on extreme values.
#
# - Skewed data also does not work well with many statistical methods. However, tree based models are not affected. **Tree based models are not affected with skewness**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Right skewed graph
# np.random.gamma(k, theta, 1000)

data = np.random.gamma(2,2,1000)
plt.hist(data, bins=30)
plt.show()

# %% [markdown]
# #### Check skewness in data
#
# **Pearson’s first coefficient of skewness**
#
# To calculate skewness values, subtract the mode from the mean, and then divide the difference by standard deviation.
#
# $$
# \gamma_1 = \frac{(\text{Mean} - \text{Mode})}{\text{Standard Deviation}}
# $$
#
# -1 (perfect negative linear relationship) to +1 (perfect positive linear relationship), including a value of 0 indicating no linear relationship
#
# Pearson’s first coefficient of skewness is helping if the data present high mode. However, if the data exhibits low mode or multiple modes, it is preferable not to use Pearson’s first coefficient, and instead, Pearson’s second coefficient may be superior, as it does not depend on the mode.
#
# **Pearson’s second coefficient of skewness**
#
# Subtract the median from the mean, multiply the difference by 3, and divide the product by the standard deviation.
#
# $$
# \gamma_2 = \frac{3(\text{Mean} - \text{Median})}{\text{Standard Deviation}}
# $$
#
#
# - For skewness values between -0.5 and 0.5, the data exhibit approximate symmetry.
#
# - Skewness values within the range of -1 and -0.5 (negative skewed) or 0.5 and 1(positive skewed) indicate slightly skewed data distributions.
#
# - Data with skewness values less than -1 (negative skewed) or greater than 1 (positive skewed) are considered highly skewed.

# %% [markdown]
# #### To check for skew in data:
#
#     df.skew().sort_values(ascending=False)
#
# #### Dealing with skew data:
#
# 1.log transformation: transform skewed distribution to a normal distribution
#
#     Not able to log 0 or negative values (add a constant to all value to ensure values > 1)
#     # Log transform a single column
#     df[‘col1’] = np.log(df[‘col1’]
#
#     # Log transform multiple columns in dataframe
#     df = df[[‘col1', ‘col2']].apply(lambda x: np.log(x))
#
# 2.Remove outliers
#
# 3.Normalize (min-max)
#
# 4.Cube root: when values are too large. Can be applied on negative values
#
# 5.Square root: applied only to positive values
#
# 6.Reciprocal

# %% [markdown]
# ### Kurtosis
#
# Kurtosis is a statistical measure that quantifies the **shape of a probability distribution.** It provides information about the tails and peakedness of the distribution compared to a normal distribution.
#
# Positive kurtosis indicates heavier tails and a more peaked distribution
#
#
# negative kurtosis suggests lighter tails and a flatter distribution
#
#
# The measure of Kurtosis refers to the tailedness of a distribution. **Tailedness refers to how often the outliers occur.** Peakedness in a data distribution is the degree to which data values are concentrated around the mean.
#
# Datasets with high kurtosis tend to have a distinct peak near the mean, decline rapidly, and have heavy tails meaning **more outliers**.
#
# Datasets with low kurtosis tend to have a flat top near the mean rather than a sharp peak, lighter tails and therefore less outliers.
#
# eg. In finance, kurtosis is used as a measure of financial risk. A large kurtosis is associated with a high level of risk for an investment because it indicates that there are high probabilities of extremely large and extremely small returns. On the other hand, a **small kurtosis** signals a moderate level of risk because the probabilities of extreme returns are relatively low.
#
# ### Types of excess kurtosis
#
# 1. Leptokurtic or heavy-tailed distribution (kurtosis more than normal distribution). kurt>3
#
# 2. Mesokurtic (kurtosis same as the normal distribution). kurt = 3
#
# 3. Platykurtic or short-tailed distribution (kurtosis less than normal distribution). kurt <3
#
# **excess kurtosis** to compare the kurtosis coefficient with that of a normal distribution.
#
# Excess kurtosis can be positive (Leptokurtic distribution), negative (Platykurtic distribution), or near zero (Mesokurtic distribution).
#
#
# **Excess kurtosis  =  Kurt – 3(kurtois of normal distribution)**
#
#
# ![image.png](attachment:image.png)
#
#
#
# Perfect symmetry and normality are indicated by both zero skewness and zero kurtosis.

# %% [markdown]
# ### Uniform Distribution
#
# A uniform distribution in machine learning refers to a probability distribution in which all possible outcomes are equally likely to occur. There is no clustering of data points around a particular value.
#
# It represents a random and unbiased sampling of the data. The probability density function (PDF) of a continuous uniform distribution over the interval [a,b]
#
# f(x; a, b) = \begin{cases}
# \frac{1}{b - a}, & \text{for } a \leq x \leq b \\
# 0, & \text{otherwise}
# \end{cases}
#
# $$
# \mu = \frac{a + b}{2}
# $$
# $$
# \sigma = \frac{b - a}{\sqrt{12}}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# a = 0 , b = 1
x = np.random.uniform(0,1,10000)

plt.hist(x, bins=30)
plt.show()

# %% [markdown]
# ### Bimodal distributions
#
# PDF has two distinct modes/peaks implying data values are most likly to occur in two regions, separated by a valley or trough where the data is less likely to occur.
#
# eg. Bimodal distributions can arise in various types of data, such as biometric measurements, economic indicators, or social media metrics. They can represent different subpopulations within the dataset, or different modes of behavior or trends over time.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate 10,000 random numbers from a bimodal distribution
x = np.concatenate((np.random.normal(-2, 1, size=5000),
   np.random.normal(2, 1, size=5000)))

plt.hist(x, bins=30)
plt.show()

# %% [markdown]
# ### references
#
# 1. https://www.w3schools.com/python/python_ml_percentile.asp
# 2. https://www.tutorialspoint.com/machine_learning/machine_learning_data_distribution.
# 3. https://reinec.medium.com/my-notes-handling-skewed-data-5984de303725
# 4. https://www.analyticsvidhya.com/blog/2021/05/shape-of-data-skewness-and-kurtosis/
